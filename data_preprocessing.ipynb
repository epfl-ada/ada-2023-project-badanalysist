# %%
import pandas as pd

# %%
df = pd.read_csv('./data/reviews_rb.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0            beer_name  beer_id brewery_name  brewery_id
# 0           0    33 Export (Gabon)   410549      Sobraga        3198  \
# 1           1  Castel Beer (Gabon)   105273      Sobraga        3198
# 2           2  Castel Beer (Gabon)   105273      Sobraga        3198
# 3           3  Castel Beer (Gabon)   105273      Sobraga        3198
# 4           4  Castel Beer (Gabon)   105273      Sobraga        3198
#
#         style  abv        date     user_name  user_id  appearance  aroma
# 0  Pale Lager  5.0  1461664800       Manslow   175852           2      4  \
# 1  Pale Lager  5.2  1487329200  MAGICuenca91   442761           2      3
# 2  Pale Lager  5.2  1466762400        Sibarh   288889           3      3
# 3  Pale Lager  5.2  1451646000       fombe89   250510           4      3
# 4  Pale Lager  5.2  1445594400    kevnic2008   122778           2      4
#
#    palate  taste  overall  rating
# 0       2      4        8     2.0  \
# 1       2      4        8     1.9
# ...

# %%
df2 = pd.read_csv('./data/m_ratings_rb.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0               beer_name  beer_id      brewery_name  brewery_id
# 0           0  Ards Bally Black Stout   155699  Ards Brewing Co.       13538  \
# 1           1  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
# 2           2  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
# 3           3  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
# 4           4  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
#
#    style  abv        date  user_name  user_id  appearance  aroma  palate
# 0  Stout  4.6  1429178400    ciaranc   151109           3      7       2  \
# 1  Stout  4.6  1427796000    Rowlymo   198957           4      7       4
# 2  Stout  4.6  1421665200    Don2711   285162           4      8       5
# 3  Stout  4.6  1380621600  genegenie   224156           5      8       3
# 4  Stout  4.6  1371549600   kiwianer    88501           4      7       4
#
# ...

# %%
df3 = pd.read_csv("./data/m_ratings_text_rb.csv")

# %%
df3.head()
# Out:
#    Unnamed: 0               beer_name  beer_id      brewery_name  brewery_id
# 0           0  Ards Bally Black Stout   155699  Ards Brewing Co.       13538  \
# 1           1  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
# 2           2  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
# 3           3  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
# 4           4  Ards Bally Black Stout   155699  Ards Brewing Co.       13538
#
#    style  abv        date  user_name  user_id  appearance  aroma  palate
# 0  Stout  4.6  1429178400    ciaranc   151109           3      7       2  \
# 1  Stout  4.6  1427796000    Rowlymo   198957           4      7       4
# 2  Stout  4.6  1421665200    Don2711   285162           4      8       5
# 3  Stout  4.6  1380621600  genegenie   224156           5      8       3
# 4  Stout  4.6  1371549600   kiwianer    88501           4      7       4
#
# ...

# %%
df3.shape
# Out:
# (1020599, 17)

# %%
df2.shape
# Out:
# (1020638, 17)
